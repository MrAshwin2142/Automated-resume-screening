# %% [markdown]
# <a href="https://colab.research.google.com/github/MrAshwin2142/Automated-resume-screening/blob/main/OOPs_Peoject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nlpcloud

client = nlpcloud.Client("gpt-oss-120b", "40a6cad257de566e5ee3916b1e71c1ead6a413ff", gpu=True)
client.code_generation(
    """Generate a C++ program that sorts a list of integers in ascending order."""
)

# %%
class NLPApp:
    def __init__(self):
        self.__database = {}
        self.__first_menu()

    def __first_menu(self):
        first_input = input("""
        Select option
        1. New member? register
        2. Already a member? login
        3. Exti
        """)
        if first_input == '1':
            self.__register()
        elif first_input == '2':
            self.__login()
        else:
            exit()


    def __second_menu(self):
        second_input = input("""
        Select option
        1. NER
        2. Language Detection
        3. Code ganration
        4. logout
        """)
        if second_input == '1':
            self.__ner()
        elif second_input == '2':
            self.__Language_Detection()
        elif second_input == '3':
            self.__code_gen()
        else:
            exit()

    def __register(self):
        name = input("Enter Name ")
        email = input("Enter Email ")
        password = input("Enter password ")

        if email in self.__database:
            print("Email Already Exist")

        else:
            self.__database[email] = [name,password]
            print("register successful. Login now")
            print(self.__database)
            self.__login()

    def __login(self):
        email = input("Enter email ")
        password = input("Enter password ")

        if email in self.__database:
            if self.__database[email][1] == password:
                print("login successfully")
                self.__second_menu()
            else:
                print("wrong password!!")
                self.__login()

        else:
            print("This email is not registered")
            self.login()

    def __ner(self):
        para = input('Enter the para')
        search__in = input('what would you like to search')
    def __Language_Detection(self):
        pass
    def __code_gen(self):
        promt = input('Enter the prompt')
        client = nlpcloud.Client("gpt-oss-120b", "40a6cad257de566e5ee3916b1e71c1ead6a413ff", gpu=True)
        response = client.code_generation(promt)
        print(response)
        self.__second_menu()

obj = NLPApp()
# Out:
#         Select option
#         1. New member? register
#         2. Already a member? login
#         3. Exti
#         1
# Enter Name 1
# Enter Email 1
# Enter password 1
# register successful. Login now
# {'1': ['1', '1']}
# Enter email 1
# Enter password 1
# login successfully
#
#         Select option
#         1. NER
#         2. Language Detection
#         3. Code ganration
#         4. logout
#         3
# Enter the promptc++ code to find number is odd or even
# ...
